# %%
import pandas as pd
import numpy as np

file = "acs2015_census_tract_data.csv"
df = pd.read_csv(file, encoding="ISO-8859-1")
df.groupby("State")
df.head()
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
#
#    Black  Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0    7.7     0.3      ...        0.5          2.3         2.1         25.0
# 1   53.3     0.0      ...        0.0          0.7         0.0         23.4
# 2   18.6     0.5      ...        0.0          0.0         2.5         19.6
# 3    3.7     1.6      ...        0.0          2.6         1.6         25.3
# 4   24.8     0.0      ...        0.0          0.6         0.9         24.8
#
# ...

# %%
clean_data = df[["State", "TotalPop","Men","Women","Hispanic","White","Black","Native",
          "Asian","Pacific","Income","IncomePerCap","Poverty",
         "Professional","Service","Office","Construction","Production",
         "Employed","PrivateWork","PublicWork","SelfEmployed","FamilyWork","Unemployment"]]
clean_data.head()
# Out:
#      State  TotalPop   Men  Women  Hispanic  White  Black  Native  Asian  \
# 0  Alabama      1948   940   1008       0.9   87.4    7.7     0.3    0.6
# 1  Alabama      2156  1059   1097       0.8   40.4   53.3     0.0    2.3
# 2  Alabama      2968  1364   1604       0.0   74.5   18.6     0.5    1.4
# 3  Alabama      4423  2172   2251      10.5   82.8    3.7     1.6    0.0
# 4  Alabama     10763  4922   5841       0.7   68.5   24.8     0.0    3.8
#
#    Pacific      ...       Service  Office  Construction  Production  Employed  \
# 0      0.0      ...          17.0    21.3          11.9        15.2       943
# 1      0.0      ...          24.7    21.5           9.4        22.0       753
# 2      0.3      ...          24.9    22.1           9.2        12.4      1373
# 3      0.0      ...          20.8    27.0           8.7        16.4      1782
# 4      0.0      ...          14.2    18.2           2.1        15.8      5037
#
# ...

# %%
clean_data.groupby("State")
clean_data.head()
# Out:
#      State  TotalPop   Men  Women  Hispanic  White  Black  Native  Asian  \
# 0  Alabama      1948   940   1008       0.9   87.4    7.7     0.3    0.6
# 1  Alabama      2156  1059   1097       0.8   40.4   53.3     0.0    2.3
# 2  Alabama      2968  1364   1604       0.0   74.5   18.6     0.5    1.4
# 3  Alabama      4423  2172   2251      10.5   82.8    3.7     1.6    0.0
# 4  Alabama     10763  4922   5841       0.7   68.5   24.8     0.0    3.8
#
#    Pacific      ...       Service  Office  Construction  Production  Employed  \
# 0      0.0      ...          17.0    21.3          11.9        15.2       943
# 1      0.0      ...          24.7    21.5           9.4        22.0       753
# 2      0.3      ...          24.9    22.1           9.2        12.4      1373
# 3      0.0      ...          20.8    27.0           8.7        16.4      1782
# 4      0.0      ...          14.2    18.2           2.1        15.8      5037
#
# ...

# %%
population = clean_data.groupby(["State"]).sum()["TotalPop"]
men = clean_data.groupby(["State"]).sum()["Men"]
women = clean_data.groupby(["State"]).sum()["Women"]
hispanic = clean_data.groupby(["State"]).mean()["Hispanic"]
white = clean_data.groupby(["State"]).mean()["White"]
black = clean_data.groupby(["State"]).mean()["Black"]
native = clean_data.groupby(["State"]).mean()["Native"]
asian = clean_data.groupby(["State"]).mean()["Asian"]
pacific = clean_data.groupby(["State"]).mean()["Pacific"]
income = clean_data.groupby(["State"]).mean()["Income"]
incomepercap = clean_data.groupby(["State"]).mean()["IncomePerCap"]
poverty = clean_data.groupby(["State"]).mean()["Poverty"]
professional = clean_data.groupby(["State"]).mean()["Professional"]
service = clean_data.groupby(["State"]).mean()["Service"]
office = clean_data.groupby(["State"]).mean()["Office"]
construction = clean_data.groupby(["State"]).mean()["Construction"]
production = clean_data.groupby(["State"]).mean()["Production"]
employed = clean_data.groupby(["State"]).mean()["Employed"]
privatework = clean_data.groupby(["State"]).mean()["PrivateWork"]
publicwork = clean_data.groupby(["State"]).mean()["PublicWork"]
selfemployed = clean_data.groupby(["State"]).mean()["SelfEmployed"]
familywork = clean_data.groupby(["State"]).mean()["FamilyWork"]
unemployment = clean_data.groupby(["State"]).mean()["Unemployment"]

state_summary = pd.DataFrame({"TotalPop":population,
                              "Men":men,
                              "Women":women,
                              "Hispanic":hispanic,
                              "White":white,
                              "Black":black,
                              "Native":native,
                              "Asian":asian,
                              "Pacific":pacific,
                              "Income":income,
                              "IncomePerCap":incomepercap,
                              "Poverty":poverty,
                              "Professional":professional,
                              "Service":service,
                              "Office":office,
                              "Construction":construction,
                              "Production":production,
                              "Employed":employed,
                              "PrivateWork":privatework,
                              "PublicWork":publicwork,
                              "SelfEmployed":selfemployed,
                              "FamilyWork":familywork,
                              "Unemployment":unemployment})
state_summary.head()
# Out:
#             TotalPop       Men     Women   Hispanic      White      Black  \
# State
# Alabama      4830620   2341093   2489527   3.751616  61.878656  31.252976
# Alaska        733375    384160    349215   5.909581  60.910180   2.848503
# Arizona      6641928   3299088   3342840  29.565921  57.120000   3.850987
# Arkansas     2958208   1451913   1506295   6.215474  71.137810  18.968759
# California  38421464  19087135  19334329  37.291875  40.215789   5.677396
#
#                Native      Asian   Pacific        Income      ...       \
# State                                                         ...
# Alabama      0.453231   1.050255  0.034354  43296.358603      ...
# Alaska      16.391018   5.450299  1.058683  70354.743902      ...
# Arizona      4.355066   2.876579  0.167632  54207.820955      ...
# Arkansas     0.522920   1.142336  0.146861  41935.633968      ...
# California   0.405292  13.052234  0.351410  67264.782303      ...
#
# ...

# %%
state_summary.to_csv("project_data.csv",
                  encoding="utf-8", index=False, header=True)
