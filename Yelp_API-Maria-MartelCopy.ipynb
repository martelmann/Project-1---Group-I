# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import yelpapi

# %%
census_pd = pd.read_csv("project_data.csv")


# Preview the data
census_pd.head()
# Out:
#         State  TotalPop       Men     Women   Hispanic      White      Black  \
# 0     Alabama   4830620   2341093   2489527   3.751616  61.878656  31.252976
# 1      Alaska    733375    384160    349215   5.909581  60.910180   2.848503
# 2     Arizona   6641928   3299088   3342840  29.565921  57.120000   3.850987
# 3    Arkansas   2958208   1451913   1506295   6.215474  71.137810  18.968759
# 4  California  38421464  19087135  19334329  37.291875  40.215789   5.677396
#
#       Native      Asian   Pacific      ...         Service     Office  \
# 0   0.453231   1.050255  0.034354      ...       18.286638  23.812766
# 1  16.391018   5.450299  1.058683      ...       17.954217  21.990964
# 2   4.355066   2.876579  0.167632      ...       20.442442  26.056832
# 3   0.522920   1.142336  0.146861      ...       17.985693  23.384088
# 4   0.405292  13.052234  0.351410      ...       19.192177  23.656127
#
#    Construction  Production     Employed  PrivateWork  PublicWork  \
# 0     10.229362   17.380511  1712.383573    78.274468   16.264085
# 1     13.470482   11.663253  2102.443114    65.080723   27.586145
# 2      9.813069    9.877096  1843.647444    78.244752   15.364818
# 3     11.154891   17.531241  1831.021866    76.176204   17.080730
# 4      9.582901   11.403417  2140.543627    77.245901   13.978921
#
#    SelfEmployed  FamilyWork  Unemployment
# 0      5.260085    0.200596     10.686723
# 1      7.121687    0.209639      9.268072
# 2      6.225149    0.165941      9.469901
# 3      6.535620    0.206423      8.529489
# 4      8.592965    0.182876     10.191290
#
# [5 rows x 24 columns]

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI('clXvdDssfwpiryl9URikQMy0kRfdf8yZBWqPSc4pk-bdiK52Awc7eAQxakB8rv0c_xlMLyU7Saw_In-8dI6UHvIN2HQC739yByp0AV_VMiltc8yIKzLnzlYMUV_aW3Yx')


def price_rating(state): 

    results = []
    states = []
    prices = []
    cuisines = []
    ratings = []
    totalreviews = []
    search_results = yelp_api.search_query(term="restaurant", location=state, limit=50, sort_by="review_count")
    for business in search_results['businesses']:
        
        try:
            price = business['price']
        except KeyError:
            price = "n/a"
        try:    
            rating= business['rating']
        except KeyError:
            rating = "n/a"
            
        try:
            cuisine=business["categories"][0]['alias']
        except KeyError:
            cuisine = "n/a"
            
        try:
            state=business["location"]['state']
        except KeyError:
            state="n/a"
        try:    
            reviews=business['review_count']
        except KeyError:
            reviews="n/a"
            
        states.append(state)
        prices.append(price)
        ratings.append(rating)
        cuisines.append(cuisine)
        totalreviews.append(reviews)
        
    food_df = pd.DataFrame({'States': states, 'Prices': prices, 'Ratings': ratings, 'Cuisines': cuisines, 'Reviews': totalreviews})
        
    return food_df
all_food_data = pd.DataFrame()

    
for state in census_pd['State']:
    all_food_data=pd.concat([all_food_data, price_rating(state)])

all_food_data
# Out:
#    States Prices  Ratings          Cuisines  Reviews
# 0      AL     $$      4.5               bbq    620.0
# 1      AL     $$      4.5           mexican    481.0
# 2      AL     $$      4.5               bbq    459.0
# 3      AL     $$      4.5      cocktailbars    448.0
# 4      AL     $$      4.0             latin    433.0
# 5      AL     $$      4.0           burgers    403.0
# 6      AL     $$      4.5          southern    347.0
# 7      AL      $      4.0           burgers    339.0
# 8      AL     $$      3.5               bbq    322.0
# 9      AL    $$$      3.5             cajun    318.0
# 10     AL      $      4.5             cafes    318.0
# 11     AL     $$      4.0  breakfast_brunch    316.0
# 12     AL     $$      4.0             pizza    315.0
# 13     AL     $$      3.5           mexican    310.0
# 14     AL     $$      4.0           italian    305.0
# 15     AL     $$      4.0               bbq    304.0
# 16     AL     $$      3.5           tex-mex    297.0
# 17     AL     $$      4.0            diners    280.0
# 18     AL     $$      4.5            french    278.0
# 19     AL      $      4.0           grocery    278.0
# 20     AL     $$      4.0              bars    278.0
# 21     AL     $$      4.0              pubs    277.0
# 22     AL     $$      3.5           seafood    277.0
# 23     AL     $$      4.5       newamerican    271.0
# 24     AL     $$      4.0             pizza    270.0
# 25     AL     $$      4.0  breakfast_brunch    267.0
# 26     AL     $$      4.0       newamerican    256.0
# 27     AL     $$      2.5        gastropubs    254.0
# 28     AL     $$      4.0              bars    252.0
# 29     AL     $$      3.5          southern    248.0
# ..    ...    ...      ...               ...      ...
# 27     WI      $      4.5          hawaiian    400.0
# 28     WI     $$      3.5  breakfast_brunch    394.0
# 29     WI     $$      4.0            diners    394.0
# 30     WI     $$      4.0           spanish    389.0
# 31     WI     $$      4.5  breakfast_brunch    388.0
# 32     WI     $$      3.5              bars    388.0
# 33     WI     $$      4.0        gastropubs    384.0
# 34     WI     $$      4.0  breakfast_brunch    377.0
# 35     WI     $$      3.5         breweries    377.0
# 36     WI    $$$      3.5            german    370.0
# 37     WI     $$      3.5              bars    361.0
# 38     WI     $$      4.0       newamerican    356.0
# 39     WI     $$      3.5             sushi    353.0
# 40     WI     $$      3.5           burgers    345.0
# 41     WI     $$      4.5              bars    345.0
# 42     WI     $$      3.5           belgian    345.0
# 43     WI     $$      3.5              bars    338.0
# 44     WI      $      3.0           mexican    335.0
# 45     WI     $$      3.5           belgian    335.0
# 46     WI     $$      4.5           grocery    331.0
# 47     WI    $$$      4.0             steak    320.0
# 48     WI     $$      4.0         wine_bars    320.0
# 49     WI     $$      3.5        mideastern    312.0
# 0      WY     $$      5.0          icecream      6.0
# 1      WY      $      4.0      tradamerican      6.0
# 2      WY    n/a      5.0      tradamerican      4.0
# 3     WSX    n/a      5.0           british      1.0
# 4      WY    n/a      5.0      tradamerican      1.0
# 5     ANT    n/a      4.0       restaurants      1.0
# 6      WY    n/a      5.0       newamerican      1.0
#
# [2507 rows x 5 columns]

# %%
max_reviews = all_food_data.groupby(['States', 'Cuisines'], sort=False)['Reviews'].max()

max_reviews
# Out:
# States  Cuisines
# AL      bbq                  620.0
#         mexican              481.0
#         cocktailbars         448.0
#         latin                433.0
#         burgers              403.0
#         southern             347.0
#         cajun                318.0
#         cafes                318.0
#         breakfast_brunch     316.0
#         pizza                315.0
#         italian              305.0
#         tex-mex              297.0
#         diners               280.0
#         french               278.0
#         grocery              278.0
#         bars                 278.0
#         pubs                 277.0
#         seafood              277.0
#         newamerican          271.0
#         gastropubs           254.0
#         sushi                243.0
#         arcades              239.0
#         vietnamese           232.0
#         falafel              232.0
#         desserts             230.0
#         steak                223.0
# AK      pizza               1995.0
#         tradamerican        1692.0
#         breakfast_brunch    1397.0
#         pubs                 850.0
#                              ...
# WI      cafes                709.0
#         bbq                  689.0
#         burgers              685.0
#         pubs                 677.0
#         southern             601.0
#         seafood              589.0
#         bars                 579.0
#         tapas                521.0
#         mexican              498.0
#         icecream             486.0
#         delis                411.0
#         tradamerican         408.0
#         bakeries             404.0
#         italian              402.0
#         hawaiian             400.0
#         diners               394.0
#         spanish              389.0
#         gastropubs           384.0
#         breweries            377.0
#         german               370.0
#         sushi                353.0
#         grocery              331.0
#         steak                320.0
#         wine_bars            320.0
#         mideastern           312.0
# WY      icecream               6.0
#         tradamerican           6.0
# WSX     british                1.0
# ANT     restaurants            1.0
# WY      newamerican            1.0
# Name: Reviews, Length: 1282, dtype: float64

# %%
idx = all_food_data.groupby(['States'])['Reviews'].transform(max) == all_food_data['Reviews']

max_reviews = all_food_data[idx]

max_reviews

max_reviews_2= max_reviews[['States','Cuisines','Reviews']]

max_reviews_2

max_reviews_2

max_reviews_2['Cuisines'].value_counts()
# Out:
# bbq                 8
# seafood             5
# breakfast_brunch    4
# newamerican         4
# pizza               3
# burgers             3
# southern            3
# diners              2
# tradamerican        2
# mexican             2
# german              2
# latin               2
# cajun               1
# mediterranean       1
# sushi               1
# restaurants         1
# sportsbars          1
# icecream            1
# chinese             1
# japanese            1
# delis               1
# steak               1
# british             1
# sandwiches          1
# french              1
# chickenshop         1
# Name: Cuisines, dtype: int64

# %%
all_food_data.set_index(['States', 'Cuisines'])

all_food_data.groupby(level=[0,1]).sum().reset_index().sort_values(['States', 'Reviews'], ascending=[1,0]).groupby('Cuisines').head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-43724a8efe0a> in <module>()
#       1 all_food_data.set_index(['States', 'Cuisines'])
#       2
# ----> 3 all_food_data.groupby(level=[0,1]).sum().reset_index().sort_values(['States', 'Reviews'], ascending=[1,0]).groupby('Cuisines').head(3)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3169                     raise ValueError('No group keys passed!')
#    3170                 else:
# -> 3171                     raise ValueError('multiple levels only valid with '
#    3172                                      'MultiIndex')
#    3173
#
# ValueError: multiple levels only valid with MultiIndex

# %%
print (business['price'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6a1f12721a0a> in <module>()
# ----> 1 print (business['price'])
#
# NameError: name 'business' is not defined
